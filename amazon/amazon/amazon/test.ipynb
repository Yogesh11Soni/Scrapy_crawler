# %%
import pandas as pd

# %%
a = pd.read_csv('/home/yogeshsoni/Desktop/scrapy/amazon/amazon/items.csv')
a
# Out:
#                                             image_link     price  \
# 0    https://m.media-amazon.com/images/I/71GLMJ7TQi...       NaN
# 1    https://m.media-amazon.com/images/I/61VuVU94Rn...    48,999
# 2    https://m.media-amazon.com/images/I/71xb2xkN5q...    48,999
# 3    https://m.media-amazon.com/images/I/61LB+d0vhe...    21,999
# 4    https://m.media-amazon.com/images/I/61u9zN1HYC...    39,999
# ..                                                 ...       ...
# 187  https://m.media-amazon.com/images/I/71Ddc1m5zc...    54,900
# 188  https://m.media-amazon.com/images/I/71RLYJvBid...  1,54,999
# 189  https://m.media-amazon.com/images/I/61ZYteSkDv...    16,199
# 190  https://m.media-amazon.com/images/I/61mSOsisDA...    94,999
# 191  https://m.media-amazon.com/images/I/61NnM1kR5c...    23,999
#
#                                           product_name
# 0                  Apple iPhone 13 (128GB) - Starlight
# 1    Apple iPhone 13 (128GB) - Midnight,Super Retin...
# ...

# %%
quotes = pd.read_csv('/home/yogeshsoni/Desktop/scrapy/quotetutorial/items_with_pagination.csv')
quotes
# Out:
#                 author                                                tag  \
# 0      Albert Einstein                change,deep-thoughts,thinking,world
# 1         J.K. Rowling                                  abilities,choices
# 2      Albert Einstein           inspirational,life,live,miracle,miracles
# 3          Jane Austen                      aliteracy,books,classic,humor
# 4       Marilyn Monroe                          be-yourself,inspirational
# ..                 ...                                                ...
# 95          Harper Lee                                better-life-empathy
# 96   Madeleine L'Engle  books,children,difficult,grown-ups,write,write...
# 97          Mark Twain                                              truth
# 98           Dr. Seuss                                      inspirational
# 99  George R.R. Martin                                         books,mind
#
#                                                 title
# ...
